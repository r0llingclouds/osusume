# %%
"""
look for an isekai anime from 2022
look for an isekai anime with female harem
look for an anime like attack on titan
look for an anime like bleach and fullmetal alchemist
look for an sports anime with ecchi



request -> json
fix genre and tags
look for genre and tags

get genre and tags from like-animes
full search
if 0? 
"""

# %%
from anilist import search_anime

search_results = search_anime(
    search_term="Attack on titan",
    # genres=["Sports", "Ecchi"],  # Using single genre parameter
    # tags=["Volleyball"],
    per_page=5
)

# Print first result details
first_anime = search_results[0]
title = first_anime['title']['english'] or first_anime['title']['romaji']
genres = first_anime['genres']
tags = [tag['name'] for tag in first_anime['tags']]

print(title)
print(genres)
print(tags)
# Out:
# Attack on Titan
# ['Action', 'Drama', 'Fantasy', 'Mystery']
# ['Revenge', 'Kaiju', 'Tragedy', 'Military', 'Male Protagonist', 'Post-Apocalyptic', 'Primarily Teen Cast', 'Super Power', 'Steampunk', 'Henshin', 'Swordplay', 'Gore', 'Memory Manipulation', 'Dystopian', 'Ensemble Cast', 'Orphan', 'Kuudere', 'Espionage', 'Cannibalism', 'Shounen', 'Coming of Age', 'Survival', 'Time Skip', 'Amnesia', 'Rural', 'Suicide', 'CGI', 'Primarily Male Cast', 'Adoption', 'Medieval']

# %%
# Out:
# 'Attack on Titan'

# %%
title = "Attack on titan"
genres = ['Action', 'Drama', 'Fantasy', 'Mystery']
tags = ['Revenge', 'Kaiju', 'Tragedy', 'Military', 'Male Protagonist', 'Post-Apocalyptic', 'Primarily Teen Cast', 'Super Power', 'Steampunk', 'Henshin', 'Swordplay', 'Gore', 'Memory Manipulation', 'Dystopian', 'Ensemble Cast', 'Orphan', 'Kuudere', 'Espionage', 'Cannibalism', 'Shounen', 'Coming of Age', 'Survival', 'Time Skip', 'Amnesia', 'Rural', 'Suicide', 'CGI', 'Primarily Male Cast', 'Adoption', 'Medieval']

# %%
from openai import OpenAI
client = OpenAI()
import json

def get_relevant_tags_and_genres(title: str, genres: list, tags: list) -> tuple[list, list]:
    response = client.responses.create(
        model="gpt-4.1",
        input="Return ONLY a python list of the 3 most relevant tags for the anime " + title + " with the genres " + str(genres) + " and the tags " + str(tags)
    )

    relevant_genres = [genres[0]]

    try:
        relevant_tags = eval(response.output_text)
    except:
        print("Error")
        print(response.output_text)
        relevant_tags = [tags[0]]
        
    return relevant_genres, relevant_tags

# %%
from anilist import search_anime

search_results = search_anime(
    search_term="Attack on titan",
    # genres=["Sports", "Ecchi"],  # Using single genre parameter
    # tags=["Volleyball"],
    per_page=5
)

# # Print all results first
print("All results:")
for anime in search_results:
    print(f"- {anime['title']['english'] or anime['title']['romaji']}")
    print(f"  Genres: {', '.join(anime['genres'])}")
    print(f"  Tags: {', '.join([tag['name'] for tag in anime['tags']])}")
    print("-" * 60)
# Out:
# All results:
# - Attack on Titan
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Revenge, Kaiju, Tragedy, Military, Male Protagonist, Post-Apocalyptic, Primarily Teen Cast, Super Power, Steampunk, Henshin, Swordplay, Gore, Memory Manipulation, Dystopian, Ensemble Cast, Orphan, Kuudere, Espionage, Cannibalism, Shounen, Coming of Age, Survival, Time Skip, Amnesia, Rural, Suicide, CGI, Primarily Male Cast, Adoption, Medieval
# ------------------------------------------------------------
# - Attack on Titan Season 2
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Survival, Post-Apocalyptic, Shapeshifting, Tragedy, Espionage, Military, Kaiju, Dystopian, Primarily Teen Cast, Gore, Revenge, Politics, Henshin, Anti-Hero, Ensemble Cast, Super Power, Shounen, Male Protagonist, Cult, Incest, Kuudere, Dissociative Identities, Coming of Age, LGBTQ+ Themes, Steampunk, Cannibalism, Primarily Male Cast, CGI, Swordplay, Female Protagonist, Primarily Adult Cast, Unrequited Love, Matriarchy, Rural, Medieval
# ------------------------------------------------------------
# - Attack on Titan Season 3
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Conspiracy, Military, Tragedy, Shapeshifting, Politics, Memory Manipulation, Dystopian, Fugitive, Male Protagonist, Revenge, Henshin, Super Power, Crime, Kaiju, Gore, Survival, Shounen, Yandere, Guns, Ensemble Cast, Matriarchy, Steampunk, Anti-Hero, Primarily Male Cast, CGI, Torture, Swordplay, Primarily Adult Cast, Crossdressing, Kuudere, Medieval
# ------------------------------------------------------------
# - Attack on Titan Final Season
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: War, Tragedy, Military, Kaiju, Anti-Hero, Revenge, Politics, Dystopian, Survival, Time Skip, Ensemble Cast, Shapeshifting, Male Protagonist, Super Power, Primarily Male Cast, Steampunk, Henshin, Coastal, Swordplay, Primarily Adult Cast, Conspiracy, Terrorism, Espionage, Gore, CGI, Body Horror, Foreign, Guns, Memory Manipulation, Matriarchy, Shounen, Philosophy, Rotoscoping, Dissociative Identities, Rural, Kuudere
# ------------------------------------------------------------
# - Attack on Titan Season 3 Part 2
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Dystopian, Military, Conspiracy, Tragedy, Survival, Memory Manipulation, Shapeshifting, Super Power, War, Shounen, Espionage, Ensemble Cast, Revenge, Henshin, Male Protagonist, Gore, Primarily Adult Cast, Anti-Hero, Steampunk, Swordplay, Primarily Male Cast, CGI, Dissociative Identities, Drugs, Kuudere, Matriarchy, Medieval, Kaiju
# ------------------------------------------------------------

# %%
from anilist import search_anime

search_results = search_anime(
    # search_term="Attack on titan",
    # genres=["Sports", "Ecchi"],  # Using single genre parameter
    tags=["Volleyball"],
    per_page=5
)

# # Print all results first
print("All results:")
for anime in search_results:
    print(f"- {anime['title']['english'] or anime['title']['romaji']}")
    print(f"  Genres: {', '.join(anime['genres'])}")
    print(f"  Tags: {', '.join([tag['name'] for tag in anime['tags']])}")
    print("-" * 60)
# Out:
# All results:
# - HAIKYU!!
#   Genres: Comedy, Drama, Sports
#   Tags: Volleyball, School Club, Male Protagonist, Primarily Male Cast, Ensemble Cast, Shounen, Primarily Teen Cast, School, Coming of Age, Fitness, Cute Boys Doing Cute Things, Kuudere
# ------------------------------------------------------------
# - HAIKYU!! 2nd Season
#   Genres: Comedy, Drama, Sports
#   Tags: Volleyball, School Club, Ensemble Cast, Primarily Teen Cast, Primarily Male Cast, Shounen, Male Protagonist, Coming of Age, School, Tomboy
# ------------------------------------------------------------
# - HAIKYU!! 3rd Season
#   Genres: Comedy, Drama, Sports
#   Tags: Volleyball, School Club, Shounen, Male Protagonist, Primarily Male Cast, Primarily Teen Cast, Ensemble Cast, School, Coming of Age
# ------------------------------------------------------------
# - HAIKYU!! TO THE TOP
#   Genres: Comedy, Drama, Sports
#   Tags: Volleyball, Male Protagonist, Shounen, School Club, Primarily Male Cast, Ensemble Cast, School, Coming of Age, Primarily Teen Cast, Twins, Tomboy
# ------------------------------------------------------------
# - HAIKYU‼ TO THE TOP Part 2
#   Genres: Comedy, Drama, Sports
#   Tags: Volleyball, Male Protagonist, Primarily Male Cast, Ensemble Cast, School Club, Primarily Teen Cast, Shounen, Coming of Age, Twins, Philosophy, Tomboy
# ------------------------------------------------------------

# %%
from typing import Optional, List, Literal
from pydantic import BaseModel
from crewai import Agent, Task, LLM
import os

# Initialize LLM (using GPT-4o from OpenAI)
llm = LLM(
    model="gpt-4.1",
    api_key=os.getenv('OPENAI_API_KEY'),
    max_tokens=2000,
    temperature=0
)

# 1 ── strict schema
class AnimeSearchParams(BaseModel):
    search_term: Optional[str] = None
    season:     Optional[Literal["WINTER", "SPRING", "SUMMER", "FALL"]] = None
    year:       Optional[int]  = None
    genres:     Optional[List[str]] = None
    tags:       Optional[List[str]] = None
    sort:       Optional[str] = None
    page:       Optional[int] = None
    per_page:   Optional[int] = None
    like_animes:   Optional[str] = None

    model_config = {"extra": "forbid"}

# 2 ── agent
mapper = Agent(
    name="AniListRequestMapper",
    role="Filter extractor",
    goal="Return only the filters in the user's request, as minimal JSON.",
    backstory="An anime librarian who knows the difference between genres and tags.",
    allow_delegation=False,
    llm=llm
)

# 3 ── task  – strict rules for genre vs tag + no nulls
OFFICIAL_GENRES = [
  "Action",
  "Adventure",
  "Comedy",
  "Drama",
  "Ecchi",
  "Fantasy",
  "Hentai",
  "Horror",
  "Mahou Shoujo",
  "Mecha",
  "Music",
  "Mystery",
  "Psychological",
  "Romance",
  "Sci-Fi",
  "Slice of Life",
  "Sports",
  "Supernatural",
  "Thriller"
]

map_request = Task(
    description=(
        "USER_REQUEST:\n"
        "{user_request}\n\n"
        "Produce **one JSON object** that validates against AnimeSearchParams.\n"
        "Rules:\n"
        f"• Only items in this list may appear in `genres`: {OFFICIAL_GENRES}.\n"
        "• Any other descriptive phrase (moods, sub‑genres like 'School Life', "
        "adjectives like 'Wholesome') must go into `tags`.\n"
        "• Title‑case every word (e.g. 'school‑life' → 'School Life').\n"
        "Don't necessarily include genres unless they are specified in the request.\n"
        "• Omit every key whose value would be null.\n\n"
        "Example:\n"
        "USER_REQUEST:  Recommend a dark fantasy from 2020.\n"
        "OUTPUT: {\"genres\": [\"Fantasy\"], \"tags\": [\"Dark\"], \"year\": 2020}"
    ),
    expected_output="A JSON dict with only the mentioned filters, no nulls.",
    output_json=AnimeSearchParams,
    agent=mapper,
)

# %%
from crewai import Crew, Process
from anilist import search_anime

# 4 ── quick demo -----------------------------------------------------------
prompt = "I want an isekai anime with a female harem"
# prompt = "I want an sportsz anime and also ecchi"
# prompt = "I want an anime like attack on titan"


crew = Crew(
    agents=[mapper],
    tasks=[map_request],
    process=Process.sequential,
)
crew.kickoff(inputs={"user_request": prompt})

params = {k: v for k, v in map_request.output.json_dict.items() if v is not None}
print(params)

# from inspect import signature
# assert set(params).issubset(signature(search_anime).parameters)
# Out:
# {'tags': ['Isekai', 'Female Harem']}

# %%
"""
AniList Search Tool for CrewAI
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
This module exposes a CrewAI‐compatible tool that lets an agent search
AniList for anime by title, season, year, genres, tags, and sort order.
"""

from typing import List, Optional, Dict, Any, Type
import requests
from pydantic import BaseModel, Field
from crewai.tools import BaseTool


# --------------------------------------------------------------------------- #
#  Low‑level helper – unchanged from your original implementation
# --------------------------------------------------------------------------- #
def _fetch_from_anilist(query: str, variables: Dict[str, Any]) -> Dict[str, Any]:
    """Send a GraphQL request to the AniList public API."""
    url = "https://graphql.anilist.co"
    resp = requests.post(url, json={"query": query, "variables": variables})
    if resp.status_code != 200:
        raise RuntimeError(
            f"AniList query failed (HTTP {resp.status_code}): {resp.text}"
        )
    return resp.json()


# --------------------------------------------------------------------------- #
#  Pydantic input schema – every argument is documented for the LLM
# --------------------------------------------------------------------------- #
class SearchAnimeToolInput(BaseModel):
    """Schema for the AniList search tool."""
    search_term: Optional[str] = Field(
        None, description="Keyword to search in titles (Romaji or English)."
    )
    season: Optional[str] = Field(
        None, description='Season filter: "WINTER", "SPRING", "SUMMER", or "FALL".'
    )
    year: Optional[int] = Field(
        None, description="Year that the season aired (e.g. 2024)."
    )
    genre: Optional[str] = Field(
        None, description="A single genre to filter by."
    )
    genres: Optional[List[str]] = Field(
        None, description="A list of genres to filter by."
    )
    tags: Optional[List[str]] = Field(
        None, description="A list of AniList tags to filter by."
    )
    sort: Optional[List[str]] = Field(
        ["POPULARITY_DESC"],
        description='List of AniList sort keys, e.g. ["SCORE_DESC"].',
    )
    page: int = Field(
        1, ge=1, description="Page number of the result set (starts at 1)."
    )
    per_page: int = Field(
        20, ge=1, le=50, description="Results per page (max 50)."
    )
    like_animes: Optional[str] = Field(
        None, description="Animes given by the user"
    )


# --------------------------------------------------------------------------- #
#  CrewAI tool definition
# --------------------------------------------------------------------------- #
class SearchAnimeTool(BaseTool):
    """
    CrewAI tool: search_anime
    -------------------------
    A high‑level search against the AniList catalogue.  Returns a list of
    anime objects with id, titles, genres, tags, averageScore, episodes,
    format, status, seasonYear, and coverImage.
    """

    name: str = "search_anime"
    description: str = (
        "Search AniList for anime using free‑text title keywords, season/year, "
        "genres, tags, and sort order. Returns an array of matching anime."
    )
    args_schema: Type[BaseModel] = SearchAnimeToolInput

    # ‑‑‑‑ core execution ‑‑‑‑ #
    def _run(  # noqa: N802 (CrewAI naming convention)
        self,
        search_term: Optional[str] = None,
        season: Optional[str] = None,
        year: Optional[int] = None,
        genre: Optional[str] = None,
        genres: Optional[List[str]] = None,
        tags: Optional[List[str]] = None,
        sort: Optional[List[str]] = None,
        page: int = 1,
        per_page: int = 20,
        like_animes: Optional[str] = None
    ) -> List[Dict[str, Any]]:
        """
        Perform the AniList query and return the raw media list.

        CrewAI automatically validates inputs with the Pydantic schema,
        so this method receives typed arguments.
        """
        query = """
        query (
          $search: String, $season: MediaSeason, $seasonYear: Int,
          $genre: String, $genres: [String], $tags: [String],
          $page: Int, $perPage: Int, $sort: [MediaSort]
        ) {
          Page(page: $page, perPage: $perPage) {
            media(
              search: $search, type: ANIME, season: $season,
              seasonYear: $seasonYear, genre: $genre, genre_in: $genres,
              tag_in: $tags, sort: $sort
            ) {
              id
              title { romaji english }
              genres
              tags { id name rank isMediaSpoiler }
              averageScore
              episodes
              format
              status
              seasonYear
              coverImage { medium }
            }
          }
        }
        """
        # First we check if the user has given a list of animes to like
        # If so, we need to retrieve the genre and tags of the animes given by the user
        like_genres = []
        like_tags = []
        if like_animes:
            like_animes = like_animes.split(",")
            for anime in like_animes:
                anime_info = search_anime(anime)
                print("anime_info")
                print(anime_info)
                if anime_info:
                    try:
                        first_anime = search_results[0]
                        single_like_genres = first_anime['genres']
                        single_like_tags = [tag['name'] for tag in first_anime['tags']]
                        print("BEFORE COMPRESSION")
                        print("like_genres")
                        print(single_like_genres)
                        print("like_tags")
                        print(single_like_tags)
                        single_like_genres, single_like_tags = get_relevant_tags_and_genres(first_anime['title']['english'], single_like_genres, single_like_tags)   
                        print("AFTER COMPRESSION")
                        print("single_like_genres")
                        print(single_like_genres)
                        print("single_like_tags")
                        print(single_like_tags)
                        like_genres.extend(single_like_genres)
                        like_tags.extend(single_like_tags)
                    except Exception as e:
                        print("Error")
                        print(e)

            like_genres = list(set(like_genres)) if like_genres else None
            like_tags = list(set(like_tags)) if like_tags else None


        # Build variables map (include only non‑None keys)
        variables: Dict[str, Any] = {
            "page": page if page else 1,
            "perPage": per_page if per_page else 20,
        }

        if genres:
            merged_genres = genres + like_genres
        else:
            merged_genres = like_genres

        if tags:
            merged_tags = tags + like_tags
        else:
            merged_tags = like_tags




        try:    
            if search_term:
                variables["search"] = search_term
            if season:
                variables["season"] = season
            if year:
                variables["seasonYear"] = year
            if genre:
                variables["genre"] = genre
            if len(merged_genres) > 0:
                variables["genres"] = merged_genres
            if len(merged_tags) > 0:
                variables["tags"] = merged_tags
            if sort:
                variables["sort"] = sort
        except Exception as e:
            print("ERROR")
            print(e)

        data = _fetch_from_anilist(query, variables)
        # Fire the request
        # print("--------------BEGIN OF CALL------------------")
        # print("query")
        # print(query)
        # print("--------------------------------")
        # print("variables")
        # print(variables)
        # print("--------------------------------")
        # print("data")
        # print(data)
        print("-" * 60)
        for anime in data["data"]["Page"]["media"]:
            print(f"- {anime['title']['english'] or anime['title']['romaji']}")
            print(f"  Genres: {', '.join(anime['genres'])}")
            print(f"  Tags: {', '.join([tag['name'] for tag in anime['tags']])}")
            print("-" * 60)

        # print("--------------------------------")
        # print(data["data"]["Page"]["media"])
        # print("""data["data"]["Page"]["media"]""")
        # print("--------------------------------")
        # print("-END OF CALL-")
        return data["data"]["Page"]["media"]

    # Optional: define async version if your crew uses asynchronous execution
    async def _arun(self, **kwargs) -> Any:  # noqa: D401
        """Asynchronous wrapper around _run."""
        return self._run(**kwargs)

# %%
from crewai import Agent, Crew, Task

anime_tool = SearchAnimeTool()

anime_researcher = Agent(
    role="Anime Researcher",
    goal="Find animes that match query obtained from the user request",
    backstory="You are a seasoned anime critic.",
    tools=[anime_tool],
)

# (Optional but typical) — wrap the work you want done in a Task
recommendation_task = Task(
    description=(
        "Using AniList, compile a list of five animes that match the query."
    ),
    expected_output="Recommendations for animes that match the query. Eeach one with a small justification.",
    agent=anime_researcher,
)

# crew = Crew(tasks=[recommendation_task], agents=[anime_researcher])

# # Kick off the crew, passing any placeholders the task needs
# result = crew.kickoff(inputs={"query": params})
# print(result)

# %%
crew = Crew(
    agents=[mapper, anime_researcher],
    tasks=[map_request, recommendation_task],
    process=Process.sequential,
)

result = crew.kickoff(inputs={"user_request": "I want an anime like akira"})
print(result)
# Out:
# anime_info
# [{'id': 47, 'title': {'romaji': 'AKIRA', 'english': 'Akira'}, 'genres': ['Action', 'Adventure', 'Horror', 'Psychological', 'Sci-Fi', 'Supernatural'], 'tags': [{'id': 108, 'name': 'Cyberpunk', 'rank': 97, 'isMediaSpoiler': False}, {'id': 93, 'name': 'Post-Apocalyptic', 'rank': 93, 'isMediaSpoiler': False}, {'id': 217, 'name': 'Dystopian', 'rank': 93, 'isMediaSpoiler': False}, {'id': 66, 'name': 'Super Power', 'rank': 88, 'isMediaSpoiler': False}, {'id': 595, 'name': 'Urban', 'rank': 87, 'isMediaSpoiler': False}, {'id': 85, 'name': 'Tragedy', 'rank': 84, 'isMediaSpoiler': True}, {'id': 82, 'name': 'Male Protagonist', 'rank': 83, 'isMediaSpoiler': False}, {'id': 88, 'name': 'Primarily Male Cast', 'rank': 80, 'isMediaSpoiler': False}, {'id': 50, 'name': 'Seinen', 'rank': 77, 'isMediaSpoiler': False}, {'id': 395, 'name': 'Delinquents', 'rank': 76, 'isMediaSpoiler': True}, {'id': 639, 'name': 'Body Horror', 'rank': 75, 'isMediaSpoiler': True}, {'id': 321, 'name': 'Urban Fantasy', 'rank': 75, 'isMediaSpoiler': False}, {'id': 173, 'name': 'Motorcycles', 'rank': 74, 'isMediaSpoiler': False}, {'id': 104, 'name': 'Anti-Hero', 'rank': 73, 'isMediaSpoiler': False}, {'id': 456, 'name': 'Conspiracy', 'rank': 73, 'isMediaSpoiler': False}, {'id': 106, 'name': 'Gangs', 'rank': 70, 'isMediaSpoiler': False}, {'id': 34, 'name': 'Military', 'rank': 68, 'isMediaSpoiler': False}, {'id': 94, 'name': 'Gore', 'rank': 68, 'isMediaSpoiler': False}, {'id': 391, 'name': 'Philosophy', 'rank': 64, 'isMediaSpoiler': False}, {'id': 648, 'name': 'Crime', 'rank': 61, 'isMediaSpoiler': False}, {'id': 1382, 'name': 'Orphan', 'rank': 60, 'isMediaSpoiler': False}, {'id': 103, 'name': 'Politics', 'rank': 54, 'isMediaSpoiler': False}, {'id': 208, 'name': 'Mythology', 'rank': 48, 'isMediaSpoiler': False}, {'id': 191, 'name': 'Aliens', 'rank': 48, 'isMediaSpoiler': True}, {'id': 100, 'name': 'Nudity', 'rank': 35, 'isMediaSpoiler': False}], 'averageScore': 79, 'episodes': 1, 'format': 'MOVIE', 'status': 'FINISHED', 'seasonYear': 1988, 'coverImage': {'medium': 'https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/bx47-4CR68arv452h.jpg'}}, {'id': 151379, 'title': {'romaji': 'Akiba Meido Sensou', 'english': 'Akiba Maid War'}, 'genres': ['Action', 'Comedy', 'Drama'], 'tags': [{'id': 199, 'name': 'Yakuza', 'rank': 99, 'isMediaSpoiler': True}, {'id': 249, 'name': 'Maids', 'rank': 98, 'isMediaSpoiler': False}, {'id': 86, 'name': 'Primarily Female Cast', 'rank': 97, 'isMediaSpoiler': False}, {'id': 648, 'name': 'Crime', 'rank': 97, 'isMediaSpoiler': True}, {'id': 106, 'name': 'Gangs', 'rank': 95, 'isMediaSpoiler': True}, {'id': 98, 'name': 'Female Protagonist', 'rank': 94, 'isMediaSpoiler': False}, {'id': 145, 'name': 'Work', 'rank': 90, 'isMediaSpoiler': False}, {'id': 157, 'name': 'Guns', 'rank': 88, 'isMediaSpoiler': True}, {'id': 39, 'name': 'Parody', 'rank': 88, 'isMediaSpoiler': True}, {'id': 109, 'name': 'Primarily Adult Cast', 'rank': 88, 'isMediaSpoiler': False}, {'id': 595, 'name': 'Urban', 'rank': 88, 'isMediaSpoiler': False}, {'id': 1647, 'name': 'Restaurant', 'rank': 88, 'isMediaSpoiler': False}, {'id': 281, 'name': 'Surreal Comedy', 'rank': 87, 'isMediaSpoiler': True}, {'id': 85, 'name': 'Tragedy', 'rank': 84, 'isMediaSpoiler': True}, {'id': 97, 'name': 'Otaku Culture', 'rank': 82, 'isMediaSpoiler': False}, {'id': 1277, 'name': 'Found Family', 'rank': 80, 'isMediaSpoiler': True}, {'id': 94, 'name': 'Gore', 'rank': 78, 'isMediaSpoiler': True}, {'id': 252, 'name': 'Revenge', 'rank': 76, 'isMediaSpoiler': True}, {'id': 83, 'name': 'Slapstick', 'rank': 75, 'isMediaSpoiler': False}, {'id': 254, 'name': 'Kemonomimi', 'rank': 73, 'isMediaSpoiler': False}, {'id': 104, 'name': 'Anti-Hero', 'rank': 70, 'isMediaSpoiler': True}, {'id': 490, 'name': 'Anachronism', 'rank': 67, 'isMediaSpoiler': False}, {'id': 111, 'name': 'War', 'rank': 64, 'isMediaSpoiler': False}, {'id': 105, 'name': 'Ensemble Cast', 'rank': 61, 'isMediaSpoiler': False}, {'id': 356, 'name': 'Gyaru', 'r ...
# BEFORE COMPRESSION
# like_genres
# ['Action', 'Drama', 'Fantasy', 'Mystery']
# like_tags
# ['Revenge', 'Kaiju', 'Tragedy', 'Military', 'Male Protagonist', 'Post-Apocalyptic', 'Primarily Teen Cast', 'Super Power', 'Steampunk', 'Henshin', 'Swordplay', 'Gore', 'Memory Manipulation', 'Dystopian', 'Ensemble Cast', 'Orphan', 'Kuudere', 'Espionage', 'Cannibalism', 'Shounen', 'Coming of Age', 'Survival', 'Time Skip', 'Amnesia', 'Rural', 'Suicide', 'CGI', 'Primarily Male Cast', 'Adoption', 'Medieval']
# AFTER COMPRESSION
# single_like_genres
# ['Action']
# single_like_tags
# ['Military', 'Post-Apocalyptic', 'Survival']
# ------------------------------------------------------------
# - Attack on Titan
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Revenge, Kaiju, Tragedy, Military, Male Protagonist, Post-Apocalyptic, Primarily Teen Cast, Super Power, Steampunk, Henshin, Swordplay, Gore, Memory Manipulation, Dystopian, Ensemble Cast, Orphan, Kuudere, Espionage, Cannibalism, Shounen, Coming of Age, Survival, Time Skip, Amnesia, Rural, Suicide, CGI, Primarily Male Cast, Adoption, Medieval
# ------------------------------------------------------------
# - Attack on Titan Season 2
#   Genres: Action, Drama, Fantasy, Mystery
#   Tags: Survival, Post-Apocalyptic, Shapeshifting, Tragedy, Espionage, Military, Kaiju, Dystopian, Primarily Teen Cast, Gore, Revenge, Politics, Henshin, Anti-Hero, Ensemble Cast, Super Power, Shounen, Male Protagonist, Cult, Incest, Kuudere, Dissociative Identities, Coming of Age, LGBTQ+ Themes, Steampunk, Cannibalism, Primarily Male Cast, CGI, Swordplay, Female Protagonist, Primarily Adult Cast, Unrequited Love, Matriarchy, Rural, Medieval
# ------------------------------------------------------------
# - DARLING in the FRANXX
#   Genres: Action, Drama, Mecha, Psychological, Romance, Sci-Fi
#   Tags: Orphan, Super Robot, Post-Apocalyptic, Dystopian, Coming of Age, Tragedy, Primarily Teen Cast, Robots, Heterosexual, Conspiracy, Found Family, Psychosexual, Femdom, Cohabitation, Kaiju, Monster Girl, Lost Civilization, Memory Manipulation, Aliens, Male Protagonist, Female Protagonist, Demons, Environmental, Love Triangle, Military, Politics, Clone, Monster Boy, Travel, Family Life, Virginity, Unrequited Love, Space, Nudity, Body Horror, Netorare, Survival, Yandere, Time Skip, Marriage, Tsundere, Drawing, Medicine, Reincarnation, Aviation, Agriculture, Fishing, Gore, Pandemic
# ------------------------------------------------------------
# - 86 EIGHTY-SIX
#   Genres: Action, Drama, Mecha, Sci-Fi
#   Tags: War, Military, Class Struggle, Tragedy, Dystopian, Survival, Politics, Proxy Battle, Female Protagonist, Post-Apocalyptic, Memory Manipulation, Robots, Male Protagonist, Conspiracy, Real Robot, Guns, Primarily Teen Cast, Ensemble Cast, Achronological Order, Ghost, Artificial Intelligence, CGI, Necromancy, Gore, Super Power, Unrequited Love, Lost Civilization, Kuudere, Travel, POV, Nudity, Body Horror
# ------------------------------------------------------------
# - Attack on Titan Final Season THE FINAL CHAPTERS Special 1
#   Genres: Action, Drama, Fantasy, Mystery, Psychological
#   Tags: Tragedy, Kaiju, Survival, Super Power, Terrorism, Military, Gore, Revenge, Shapeshifting, Anti-Hero, Foreign, Dystopian, Post-Apocalyptic, Primarily Adult Cast, Ensemble Cast, Time Skip, CGI, Shounen, Female Protagonist, Male Protagonist, Class Struggle, Kuudere, Suicide, Ships, Aviation, Tanned Skin, Heterosexual, Matriarchy
# ------------------------------------------------------------
# 1. **Attack on Titan (Shingeki no Kyojin)**
#    - This anime immerses audiences in a dystopian world where humanity is on the brink of extinction due to giant humanoid creatures known as Titans. The intense action and dramatic themes, coupled with psychological horror elements, will resonate with fans of Akira, especially those who appreciate strong narratives and complex character arcs.
#    - ![Cover Image](https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/bx16498-buvcRTBx4NSm.jpg)
#
# 2. **Attack on Titan Season 2 (Shingeki no Kyojin 2)**
#    - Continuing the gripping story of humanity's fight against Titan threats, this season delves deeper into the mysteries surrounding the Titans and features significant character development and emotional stakes, making it a must-watch for those who enjoyed the original series and Akira's thematic depth.
#    - ![Cover Image](https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/bx20958-HuFJyr54Mmir.jpg)
#
# 3. **DARLING in the FRANXX**
#    - A futuristic series with psychological themes, DARLING in the FRANXX explores deep emotional connections amid a post-apocalyptic setting, echoing Akira's elements of youth and rebellion against oppressive forces. The mecha action combined with profound character struggles makes it appealing to fans of the genre.
#    - ![Cover Image](https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/nx99423-8MBxtwCeHf8B.png)
#
# 4. **86: Eighty Six**
#    - This anime tackles serious themes related to war, class struggle, and survival in a dystopian society. With a heavy focus on its characters' emotional struggles and societal themes, it embodies many comparable elements to Akira, making it a gripping watch for fans seeking impactful storytelling.
#    - ![Cover Image](https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/bx116589-qT34qzsZtk9V.jpg)
#
# 5. **Attack on Titan: The Final Season - Kanketsu-hen Zenpen**
#    - This special continues to showcase the intense action and dramatic revelations of the Attack on Titan story arc with high stakes, thrilling moments, and character resolutions that might echo the emotional and action-packed journey seen in Akira.
#    - ![Cover Image](https://s4.anilist.co/file/anilistcdn/media/anime/cover/small/bx146984-GXrLeT6vQqyP.jpg)
